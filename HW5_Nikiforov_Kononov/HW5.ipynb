# %%
import nltk
import math
import os
import string
import spacy 
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
import re

nlp = spacy.load("en_core_web_sm")
#nltk.download('punkt') #Необходимо для первого запуска.


#Для работы НЕОБХОДИМО, ЧТОБЫ СОДЕРЖИМОЕ В ПАПКЕ "all_tf_idf" БЫЛО РАЗАРХИВИРОВАНО.


def find_docs(request):
    stop_words = set(stopwords.words("english"))
    request = request.lower()
    r = re.compile("^[a-z]+$") 
    clear_req = nltk.word_tokenize(request)
    clear_req = [word for word in filter(r.match, clear_req)] #Удаление не английских слов.
    clear_req = [word for word in clear_req if not word in stop_words] #Удаление стоп-слов.
    for word in clear_req:
        word = nlp(word)[0].lemma #Замена слов на леммы.
    clear_req = set(clear_req) #Удаление повторений.
    dir = 'all_tf_idf/'
    filelist = os.listdir(dir)
    dict = {}
    value_dict = {}
    #for lemma in clear_req:
    for i in filelist:
        file = open(os.path.join('all_tf_idf/'+ i), 'r', encoding="utf-8")
        text = file.readlines()
        text.pop(0)
        word_count = 0
        file_num = re.findall(r'\d+', i)[0]
        for line in text:
            arr = line.split(' ')
            if arr[0] in clear_req:
                word_count += 1
                if file_num in dict: 
                    dict[file_num].append(float(arr[2]))
                else:
                    dict[file_num] = [float(arr[2])]
            if word_count == len(clear_req):
                value_dict[file_num] = [math.sqrt(sum(map(lambda x:x*x, dict[file_num])))]
                break
    index = open(os.path.join('index.txt'), 'r', encoding="utf-8")
    text = index.readlines()
    for line in text:
        arr = line.split(' ')
        if arr[0] in value_dict:
            value_dict[arr[0]].append(arr[1])
    value_dict = sorted(value_dict.items(), key=lambda item: item[1], reverse=True)  
    for value in value_dict:
        print('{}\n'.format(value[1][1]))

        
if __name__ == "__main__":
    
    while True:
        request = input()
        if request == "exit()": #Написать "exit()" для выхода.
            break
        find_docs(request)    
    print("Done.")
# Out:
# wikipedia free buy
# https://en.wikipedia.org/wiki/Nintendo_64
#
#
# https://en.wikipedia.org/wiki/Special:Random
#
#
# https://en.wikipedia.org/wiki/Wolfgang_Boettcher
#
#
# https://en.wikipedia.org/wiki/Hard_Punishments
#
#
# https://en.wikipedia.org/wiki/Free_content
#
#
# https://en.wikipedia.org/wiki/Virtual_Console
#
#
# https://en.wikipedia.org/wiki/Portal:The_arts
#
#
# https://en.wikipedia.org/wiki/Nintendo
#
#
# https://en.wikipedia.org/wiki/Portal:Technology
#
#
# https://en.wikipedia.org/wiki/Willa_Cather
#
#
# https://en.wikipedia.org/wiki/Wikipedia:About
#
#
# https://en.wikipedia.org/wiki/Bath_Abbey
#
#
# https://en.wikipedia.org/wiki/Help:Introduction_to_Wikipedia
#
#
# https://en.wikipedia.org/wiki/Bath,_Somerset
#
#
# https://en.wikipedia.org/wiki/COVID-19_pandemic
#
#
# https://en.wikipedia.org/wiki/File:Bath_Abbey_Eastern_Stained_Glass,_Somerset,_UK_-_Diliff.jpg
#
#
# https://en.wikipedia.org/wiki/Wikipedia:File_Upload_Wizard
#
#
# https://en.wikipedia.org/wiki/Special:MyTalk
#
#
# https://en.wikipedia.org/wiki/Portal:Current_events
#
#
# https://en.wikipedia.org/wiki/Wikipedia:Reference_desk
#
#
# https://en.wikipedia.org/wiki/2021_Myanmar_protests
#
#
# https://en.wikipedia.org/wiki/Wikipedia:In_the_news/Candidates
#
#
# https://en.wikipedia.org/wiki/Template:POTD/2021-02-26
#
#
# https://en.wikipedia.org/wiki/Template:POTD/2021-02-25
#
#
# https://en.wikipedia.org/wiki/Template:POTD/2021-02-27
#
#
# https://en.wikipedia.org/wiki/Richard_Platt_(brewer)
#
#
# https://en.wikipedia.org/wiki/Wii
#
#
# https://en.wikipedia.org/wiki/Main_Page
#
#
# https://en.wikipedia.org/wiki/Help:Introduction
#
#
# https://en.wikipedia.org/wiki/Snowboarding_video_game
#
#
# https://en.wikipedia.org/wiki/File:Richard_Platt_(detail).jpeg
#
#
# https://en.wikipedia.org/wiki/List_of_days_of_the_year
#
#
# https://en.wikipedia.org/wiki/Wikipedia:Contact_us
#
#
# https://en.wikipedia.org/wiki/Wikipedia:General_disclaimer
#
#
# https://en.wikipedia.org/wiki/File:NaomiOsaka-NovakDjokovic-2021AusOpenComposite.jpg
#
#
# https://en.wikipedia.org/wiki/Wikipedia
#
#
# https://en.wikipedia.org/wiki/Tuskegee_Syphilis_Study
#
#
# https://en.wikipedia.org/wiki/Secondary_school
#
#
# https://en.wikipedia.org/wiki/Template_talk:Did_you_know
#
#
# https://en.wikipedia.org/wiki/1973_New_York_City_mayoral_election
#
#
# https://en.wikipedia.org/wiki/Aldenham_School
#
#
# https://en.wikipedia.org/wiki/Novak_Djokovic
#
#
# https://en.wikipedia.org/wiki/Albert_H._Blumenthal
#
#
# https://en.wikipedia.org/wiki/File:Sir_CV_Raman.JPG
#
#
# https://en.wikipedia.org/wiki/Wikipedia:News
#
#
# https://en.wikipedia.org/wiki/Wikipedia:Featured_pictures
#
#
# https://en.wikipedia.org/wiki/Worshipful_Company_of_Brewers
#
#
# https://en.wikipedia.org/wiki/Wikimedia_Foundation
#
#
# https://en.wikipedia.org/wiki/1080%C2%B0_Avalanche
#
#
# https://en.wikipedia.org/wiki/1844
#
#
# https://en.wikipedia.org/wiki/Logging_camp
#
#
# https://en.wikipedia.org/wiki/Ch%C3%B6re_f%C3%BCr_Doris
#
#
# https://en.wikipedia.org/wiki/Parish_church
#
#
# https://en.wikipedia.org/wiki/Wikipedia:Village_pump
#
#
# https://en.wikipedia.org/wiki/Raymond_Cauchetier
#
#
# https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
#
#
# https://en.wikipedia.org/wiki/Tichborne_baronets
#
#
# https://en.wikipedia.org/wiki/Portal:Society
#
#
# https://en.wikipedia.org/wiki/Wikipedia:Contents/Portals
#
#
# https://en.wikipedia.org/wiki/Guan_Bee_Ong
#
#
# https://en.wikipedia.org/wiki/1992_Football_League_Third_Division_play-off_Final
#
#
# https://en.wikipedia.org/wiki/Academy_of_Interactive_Arts_%26_Sciences
#
#
# https://en.wikipedia.org/wiki/Doris_Stockhausen
#
#
# https://en.wikipedia.org/wiki/Count_Gibson
#
#
# https://en.wikipedia.org/wiki/D._Pandian
#
#
# https://en.wikipedia.org/wiki/Fan_vault
#
#
# https://en.wikipedia.org/wiki/John_Geddert
#
#
# https://en.wikipedia.org/wiki/Help:Contents
#
#
# https://en.wikipedia.org/wiki/Koesbini
#
#
# https://en.wikipedia.org/wiki/Zamfara_State
#
#
# https://en.wikipedia.org/wiki/Wikipedia:Selected_anniversaries/February
#
#
# https://en.wikipedia.org/wiki/Thomas_Cushing
#
#
# https://en.wikipedia.org/wiki/USS_Princeton_(1843)
#
#
# https://en.wikipedia.org/wiki/William_Zorach
#
#
# https://en.wikipedia.org/wiki/University_of_Hong_Kong
#
#
# https://en.wikipedia.org/wiki/Ingenuity_(helicopter)
#
#
# https://en.wikipedia.org/wiki/Flying_buttress
#
#
# https://en.wikipedia.org/wiki/Wikipedia:Contents
#
#
# https://en.wikipedia.org/wiki/Wikipedia:Help_desk
#
# https://en.wikipedia.org/wiki/Kalevala
#
#
# https://en.wikipedia.org/wiki/Asser_Levy_Recreation_Center
#
#
# https://en.wikipedia.org/wiki/List_of_heads_of_the_Serbian_Orthodox_Church
#
#
# https://en.wikipedia.org/wiki/Ronald_Pickup
#
#
# https://en.wikipedia.org/wiki/Level_(video_games)
#
#
# https://en.wikipedia.org/wiki/Help:Your_first_article
#
#
# https://en.wikipedia.org/wiki/2021_Australian_Open_%E2%80%93_Women%27s_Singles
#
#
# https://en.wikipedia.org/wiki/Oryzomys_gorgasi
#
#
# https://en.wikipedia.org/wiki/Virtual_camera_system
#
#
# https://en.wikipedia.org/wiki/2021_Australian_Open_%E2%80%93_Men%27s_Singles
#
#
# https://en.wikipedia.org/wiki/Wikipedia:Community_portal
#
#
# https://en.wikipedia.org/wiki/1080%C2%B0_Snowboarding
#
#
# https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics
#
#
# https://en.wikipedia.org/wiki/Wikipedia:Local_Embassy
#
#
# https://en.wikipedia.org/wiki/Perjury
#
#
# https://en.wikipedia.org/wiki/Talk:Main_Page
#
#
# https://en.wikipedia.org/wiki/1874
#
#
# https://en.wikipedia.org/wiki/1928
#
#
# https://en.wikipedia.org/wiki/Raman_scattering
#
#
# https://en.wikipedia.org/wiki/Wikipedia:Recent_additions
#
#
# https://en.wikipedia.org/wiki/March_1
#
#
# https://en.wikipedia.org/wiki/Porfirije,_Serbian_Patriarch
#
#
# https://en.wikipedia.org/wiki/Mars_2020
#
#
# https://en.wikipedia.org/wiki/Portal:Science
#
#
# https://en.wikipedia.org/wiki/Clayton_and_Bell
#
#
# https://en.wikipedia.org/wiki/February_28
#
#
# https://en.wikipedia.org/wiki/February_27
#
#
# https://en.wikipedia.org/wiki/Grey_currawong
#
#
# https://en.wikipedia.org/wiki/Wikipedia:Picture_of_the_day/Archive
#
#
# https://en.wikipedia.org/wiki/Nativity_of_Jesus
#
#
# https://en.wikipedia.org/wiki/User:Diliff
#
#
# https://en.wikipedia.org/wiki/2021_Australian_Open
#
#
# https://en.wikipedia.org/wiki/Wikipedia:Today%27s_featured_article/February_2021
#
#
# https://en.wikipedia.org/wiki/Portal:Biography
#
#
# https://en.wikipedia.org/wiki/Nintendo_Entertainment_Analysis_%26_Development
#
#
# https://en.wikipedia.org/wiki/English_language
#
#
# https://en.wikipedia.org/wiki/Perseverance_(rover)
#
#
# https://en.wikipedia.org/wiki/Portal:Geography
#
#
# https://en.wikipedia.org/wiki/Potomac_River
#
#
# https://en.wikipedia.org/wiki/Tennis
#
#
# https://en.wikipedia.org/wiki/2001
#
#
# https://en.wikipedia.org/wiki/GameCube
#
#
# https://en.wikipedia.org/wiki/Tichborne_case
#
#
# https://en.wikipedia.org/wiki/Listed_building
#
#
# https://en.wikipedia.org/wiki/Portal:History
#
#
# https://en.wikipedia.org/wiki/Naomi_Osaka
#
#
# https://en.wikipedia.org/wiki/Deaths_in_2021
#
#
# https://en.wikipedia.org/wiki/C._V._Raman
#
#
# https://en.wikipedia.org/wiki/Special:WhatLinksHere/Main_Page
#
#
# https://en.wikipedia.org/wiki/Special:RecentChanges
#
#
# https://en.wikipedia.org/wiki/Special:MyContributions
#
#
# https://en.wikipedia.org/wiki/Special:Statistics
#
#
# https://en.wikipedia.org/wiki/Special:SpecialPages
#
#
# exit()
# Done.
